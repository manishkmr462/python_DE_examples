# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, np.nan],
        "Sex": ["male", "male", "female"],
    }
)

# %%
df
# Out:
#                        Name   Age     Sex
# 0   Braund, Mr. Owen Harris  22.0    male
# 1  Allen, Mr. William Henry  35.0    male
# 2  Bonnell, Miss. Elizabeth   NaN  female

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Age"]
# Out:
# 0    22.0
# 1    35.0
# 2     NaN
# Name: Age, dtype: float64

# %%
ages = pd.Series([22, 35, 58], name="Age", dtype=np.float32)

# %%
ages
# Out:
# 0    22.0
# 1    35.0
# 2    58.0
# Name: Age, dtype: float32

# %%
df["Age"].max()
# Out:
# np.float64(35.0)

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   28.500000
# std     9.192388
# min    22.000000
# 25%    25.250000
# 50%    28.500000
# 75%    31.750000
# max    35.000000

# %%
t_df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv')

# %%
t_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t_df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
with pd.read_csv('titanic.csv', chunksize= 10) as tf_obj:
    for chunk in tf_obj:
        chunked_df = pd.DataFrame(chunk)
        print(chunked_df)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
t_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t_df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
t_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
t_df.to_excel("titanic.xlsx", sheet_name="passengers", index=False)

# %%
t_df.to_excel("titanic_2.xls", sheet_name="passengers", index=False, engine='xlsxwriter')

# %%
t_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
t_df[["Age","Cabin"]].shape
# Out:
# (891, 2)

# %%
t_df["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
above_35 = t_df[t_df["Age"] > 35]
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t_df[t_df["Pclass"].isin([2, 3])]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss Laina
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 7              8         0       3            Palsson, Master Gosta Leonard
# ..           ...       ...     ...                                      ...
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 885          886         0       3     Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                    Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 890          891         0       3                      Dooley, Mr. Patrick
#
# ...

# %%
non_adult_p1 = t_df[(t_df["Pclass"] == 1) & (t_df["Age"] < 18)]

# %%
non_adult_p1.shape
# Out:
# (12, 12)

# %%
non_adult_p1
# Out:
#      PassengerId  Survived  Pclass  \
# 297          298         0       1
# 305          306         1       1
# 307          308         1       1
# 329          330         1       1
# 435          436         1       1
# 445          446         1       1
# 504          505         1       1
# 550          551         1       1
# 689          690         1       1
# 781          782         1       1
# 802          803         1       1
# 853          854         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 297                        Allison, Miss Helen Loraine  female   2.00      1
# 305                      Allison, Master Hudson Trevor    male   0.92      1
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.00      1
# 329                        Hippach, Miss Jean Gertrude  female  16.00      0
# 435                           Carter, Miss Lucile Polk  female  14.00      1
# ...

# %%
non_adult_p1[non_adult_p1["Sex"] == 'male'].shape
# Out:
# (4, 12)

# %%
age_no_na = t_df[t_df["Age"].notna()]
age_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
age_na = t_df[t_df["Age"].isna()]
age_na
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 5              6         0       3                         Moran, Mr. James
# 17            18         1       2             Williams, Mr. Charles Eugene
# 19            20         1       3                  Masselmani, Mrs. Fatima
# 26            27         0       3                  Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss Ellen "Nellie"
# ..           ...       ...     ...                                      ...
# 859          860         0       3                         Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss Dorothy Edith "Dolly"
# 868          869         0       3              van Melkebeke, Mr. Philemon
# 878          879         0       3                       Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
#
# ...

# %%
adult_names = t_df.loc[t_df["Age"] > 35, "Name"]
type(adult_names)
# Out:
# pandas.core.series.Series

# %%
adult_names_ages = t_df.loc[t_df["Age"] > 35, ["Name","Age"]]
type(adult_names_ages)
# Out:
# pandas.core.frame.DataFrame

# %%
t_df.iloc[9:25, 2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                     Sandstrom, Miss Marguerite Rut  female
# 11       1                            Bonnell, Miss Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3                Vestrom, Miss Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                                Rice, Master Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
t_df.iloc[0:3, 3] = "anonymous"

# %%
t_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                       anonymous    male  22.0      1      0
# 1                                       anonymous  female  38.0      1      0
# 2                                       anonymous  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %%
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/air_quality_no2.csv", index_col=0, parse_dates=True)

# %%
air_quality.head(10)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# 2019-05-07 07:00:00              NaN           72.4            26.0
# 2019-05-07 08:00:00              NaN           77.7            32.0
# 2019-05-07 09:00:00              NaN           67.9            32.0
# 2019-05-07 10:00:00              NaN           56.0            28.0
# 2019-05-07 11:00:00              NaN           34.5            21.0

# %%
air_quality.index
# Out:
# DatetimeIndex(['2019-05-07 02:00:00', '2019-05-07 03:00:00',
#                '2019-05-07 04:00:00', '2019-05-07 05:00:00',
#                '2019-05-07 06:00:00', '2019-05-07 07:00:00',
#                '2019-05-07 08:00:00', '2019-05-07 09:00:00',
#                '2019-05-07 10:00:00', '2019-05-07 11:00:00',
#                ...
#                '2019-06-20 17:00:00', '2019-06-20 18:00:00',
#                '2019-06-20 19:00:00', '2019-06-20 20:00:00',
#                '2019-06-20 21:00:00', '2019-06-20 22:00:00',
#                '2019-06-20 23:00:00', '2019-06-21 00:00:00',
#                '2019-06-21 01:00:00', '2019-06-21 02:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=1035, freq=None)

# %%
air_quality.plot(figsize=[15, 7])
plt.show()

# %%
air_quality["station_paris"].plot(figsize=[15, 7])
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)

# %%
fig, axs = plt.subplots(figsize=(12, 4))
air_quality.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration")
# Out:
# Text(0, 0.5, 'NO$_2$ concentration')

# %%
fig.savefig("no2_concentrations.png")

# %%
fig.savefig("no2_concentrations.svg")

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# ...

# %%
air_quality["air_quality_avg_all"] = sum([air_quality["station_london"], air_quality["station_antwerp"], air_quality["station_paris"]])/3

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic  air_quality_avg_all
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# ...

# %%
air_quality["air_quality_good_all"] = air_quality["air_quality_avg_all"] < 50

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic  air_quality_avg_all  \
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# ...

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "air_quality_good_all": "air_quality_good_all_loc"
    }
)
air_quality_renamed = air_quality_renamed.rename_axis(index={"datetime": "timestamp"})

# %%
air_quality_renamed
# Out:
#                      station_antwerp  station_paris  station_london  \
# timestamp
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic  air_quality_avg_all  \
# timestamp
# 2019-05-07 02:00:00               43.286                  NaN
# ...

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic  air_quality_avg_all  \
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# ...

# %%
df_num = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])

# %%
df_num
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
df_num.shape
# Out:
# (3, 2)

# %%
df_num.apply(np.sqrt)
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
df_num.apply(np.sum, axis=0)
# Out:
# A    12
# B    27
# dtype: int64

# %%
df_num.apply(np.sum, axis=1)
# Out:
# 0    13
# 1    13
# 2    13
# dtype: int64

# %%
t_df["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
t_df["Age"].median()
# Out:
# np.float64(28.0)

# %%
t_df["Age"].std()
# Out:
# np.float64(14.526497332334042)

# %%
t_df[["Age","Fare"]].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
t_df.agg(
    {
        "Age": ["min", "max", "median", "mean", "skew"],
        "Fare": ["min", "max", "median", "mean", "skew"],
    }
)
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# mean    29.699118   32.204208
# skew     0.389108    4.787317

# %%
t_df["Age"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
t_df["Fare"].plot(figsize=[12,6],kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
t_df[["Pclass", "Age"]].groupby("Pclass").mean()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
t_df.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
t_df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
t_df.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
t_df["Age"].value_counts(dropna=False)
# Out:
# Age
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 24.50      1
# 0.67       1
# 0.42       1
# 34.50      1
# 74.00      1
# Name: count, Length: 89, dtype: int64

# %%
t_df.sort_values(by="Age", ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
air_quality = pd.read_csv(
    "https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/air_quality_long.csv", index_col="date.utc", parse_dates=True
)

# %%
no2 = air_quality[air_quality["parameter"] == "no2"]

# %%
no2
# Out:
#                              city country            location parameter  \
# date.utc
# 2019-06-21 00:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 23:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 22:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 21:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 20:00:00+00:00   Paris      FR             FR04014       no2
# ...                           ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-06-21 00:00:00+00:00   20.0  µg/m³
# ...

# %%
no2_subset = no2.sort_index().groupby(["location"]).head()

# %%
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 03:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 04:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 04:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# ...

# %%
air_quality_subset = no2_subset.pivot(columns="location", values="value")

# %%
type(air_quality_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
air_quality.pivot_table(
    values="value", index="location", columns="parameter", aggfunc="mean",  margins=True,
)
# Out:
# parameter                 no2       pm25        All
# location
# BETR801             26.950920  23.169492  24.982353
# FR04014             29.374284        NaN  29.374284
# London Westminster  29.740050  13.443568  21.491708
# All                 29.430316  14.386849  24.222743

# %%
no2_pivoted = no2.pivot(columns="location", values="value").reset_index()

# %%
no2_pivoted
# Out:
# location                  date.utc  BETR801  FR04014  London Westminster
# 0        2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 1        2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2        2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 3        2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 4        2019-04-09 05:00:00+00:00     46.5     59.5                41.0
# ...                            ...      ...      ...                 ...
# 1700     2019-06-20 20:00:00+00:00      NaN     21.4                 NaN
# 1701     2019-06-20 21:00:00+00:00      NaN     24.9                 NaN
# 1702     2019-06-20 22:00:00+00:00      NaN     26.5                 NaN
# 1703     2019-06-20 23:00:00+00:00      NaN     21.8                 NaN
# 1704     2019-06-21 00:00:00+00:00      NaN     20.0                 NaN
#
# [1705 rows x 4 columns]

# %%
no_2 = no2_pivoted.melt(id_vars="date.utc")

# %%
no_2.head(20)
# Out:
#                     date.utc location  value
# 0  2019-04-09 01:00:00+00:00  BETR801   22.5
# 1  2019-04-09 02:00:00+00:00  BETR801   53.5
# 2  2019-04-09 03:00:00+00:00  BETR801   54.5
# 3  2019-04-09 04:00:00+00:00  BETR801   34.5
# 4  2019-04-09 05:00:00+00:00  BETR801   46.5
# 5  2019-04-09 06:00:00+00:00  BETR801   50.0
# 6  2019-04-09 07:00:00+00:00  BETR801   38.5
# 7  2019-04-09 08:00:00+00:00  BETR801   39.0
# 8  2019-04-09 09:00:00+00:00  BETR801   35.0
# 9  2019-04-09 10:00:00+00:00  BETR801   33.5
# 10 2019-04-09 11:00:00+00:00  BETR801   28.5
# 11 2019-04-09 12:00:00+00:00  BETR801   30.0
# 12 2019-04-09 13:00:00+00:00  BETR801   27.5
# 13 2019-04-09 14:00:00+00:00  BETR801    NaN
# 14 2019-04-09 15:00:00+00:00  BETR801    NaN
# 15 2019-04-09 16:00:00+00:00  BETR801    NaN
# 16 2019-04-09 17:00:00+00:00  BETR801    NaN
# 17 2019-04-09 18:00:00+00:00  BETR801    NaN
# 18 2019-04-09 19:00:00+00:00  BETR801    NaN
# 19 2019-04-09 20:00:00+00:00  BETR801    NaN

# %% [markdown]
# Long table format -> having more number of records and less number of columns
# Wide table format -> having more number of columns and less number of records

# %%
air_quality_no2 = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/air_quality_no2_long.csv",
                              parse_dates=True)

air_quality_no2 = air_quality_no2[["date.utc", "location",
                                   "parameter", "value"]]

air_quality_no2.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 2  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 3  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 4  2019-06-20 20:00:00+00:00  FR04014       no2   21.4

# %%
air_quality_pm25 = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/air_quality_pm25_long.csv",
                               parse_dates=True)


air_quality_pm25 = air_quality_pm25[["date.utc", "location",
                                     "parameter", "value"]]


air_quality_pm25.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5

# %%
air_quality_pm25.shape
# Out:
# (1110, 4)

# %%
air_quality_no2.shape
# Out:
# (2068, 4)

# %%
air_quality_  = pd.concat([air_quality_pm25, air_quality_no2], axis=0)

# %%
air_quality_
# Out:
#                        date.utc            location parameter  value
# 0     2019-06-18 06:00:00+00:00             BETR801      pm25   18.0
# 1     2019-06-17 08:00:00+00:00             BETR801      pm25    6.5
# 2     2019-06-17 07:00:00+00:00             BETR801      pm25   18.5
# 3     2019-06-17 06:00:00+00:00             BETR801      pm25   16.0
# 4     2019-06-17 05:00:00+00:00             BETR801      pm25    7.5
# ...                         ...                 ...       ...    ...
# 2063  2019-05-07 06:00:00+00:00  London Westminster       no2   26.0
# 2064  2019-05-07 04:00:00+00:00  London Westminster       no2   16.0
# 2065  2019-05-07 03:00:00+00:00  London Westminster       no2   19.0
# 2066  2019-05-07 02:00:00+00:00  London Westminster       no2   19.0
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
#
# [3178 rows x 4 columns]

# %%
type(air_quality_["date.utc"])
# Out:
# pandas.core.series.Series

# %%
stations_coord = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/air_quality_stations.csv")

# %%
stations_coord.head()
# Out:
#   location  coordinates.latitude  coordinates.longitude
# 0  BELAL01              51.23619                4.38522
# 1  BELHB23              51.17030                4.34100
# 2  BELLD01              51.10998                5.00486
# 3  BELLD02              51.12038                5.02155
# 4  BELR833              51.32766                4.36226

# %%
stations_coord.shape
# Out:
# (66, 3)

# %%
air_quality.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
air_quality.shape
# Out:
# (5272, 6)

# %%
air_quality_joined = pd.merge(air_quality, stations_coord, how="left", on="location")

# %%
air_quality_joined
# Out:
#            city country            location parameter  value   unit  \
# 0     Antwerpen      BE             BETR801      pm25   18.0  µg/m³
# 1     Antwerpen      BE             BETR801      pm25    6.5  µg/m³
# 2     Antwerpen      BE             BETR801      pm25   18.5  µg/m³
# 3     Antwerpen      BE             BETR801      pm25   16.0  µg/m³
# 4     Antwerpen      BE             BETR801      pm25    7.5  µg/m³
# ...         ...     ...                 ...       ...    ...    ...
# 6943     London      GB  London Westminster       no2   41.0  µg/m³
# 6944     London      GB  London Westminster       no2   41.0  µg/m³
# 6945     London      GB  London Westminster       no2   41.0  µg/m³
# 6946     London      GB  London Westminster       no2   67.0  µg/m³
# 6947     London      GB  London Westminster       no2   67.0  µg/m³
#
#       coordinates.latitude  coordinates.longitude
# 0                 51.20966                4.43182
# ...

# %%
air_quality_parameters = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/air_quality_parameters.csv")

# %%
air_quality_parameters.head()
# Out:
#      id                                        description  name
# 0    bc                                       Black Carbon    BC
# 1    co                                    Carbon Monoxide    CO
# 2   no2                                   Nitrogen Dioxide   NO2
# 3    o3                                              Ozone    O3
# 4  pm10  Particulate matter less than 10 micrometers in...  PM10

# %%
air_quality_joined_2 = pd.merge(air_quality, air_quality_parameters,
                       how='left', left_on='parameter', right_on='id')

# %%
air_quality_joined_2
# Out:
#            city country            location parameter  value   unit    id  \
# 0     Antwerpen      BE             BETR801      pm25   18.0  µg/m³  pm25
# 1     Antwerpen      BE             BETR801      pm25    6.5  µg/m³  pm25
# 2     Antwerpen      BE             BETR801      pm25   18.5  µg/m³  pm25
# 3     Antwerpen      BE             BETR801      pm25   16.0  µg/m³  pm25
# 4     Antwerpen      BE             BETR801      pm25    7.5  µg/m³  pm25
# ...         ...     ...                 ...       ...    ...    ...   ...
# 5267     London      GB  London Westminster       no2   41.0  µg/m³   no2
# 5268     London      GB  London Westminster       no2   41.0  µg/m³   no2
# 5269     London      GB  London Westminster       no2   41.0  µg/m³   no2
# 5270     London      GB  London Westminster       no2   67.0  µg/m³   no2
# 5271     London      GB  London Westminster       no2   67.0  µg/m³   no2
#
#                                             description   name
# ...

# %%
air_quality_["date.utc"]
# Out:
# 0       2019-06-18 06:00:00+00:00
# 1       2019-06-17 08:00:00+00:00
# 2       2019-06-17 07:00:00+00:00
# 3       2019-06-17 06:00:00+00:00
# 4       2019-06-17 05:00:00+00:00
#                   ...
# 2063    2019-05-07 06:00:00+00:00
# 2064    2019-05-07 04:00:00+00:00
# 2065    2019-05-07 03:00:00+00:00
# 2066    2019-05-07 02:00:00+00:00
# 2067    2019-05-07 01:00:00+00:00
# Name: date.utc, Length: 3178, dtype: object

# %%
air_quality_["date.utc"] = pd.to_datetime(air_quality_["date.utc"])

# %%
air_quality_["date.utc"]
# Out:
# 0      2019-06-18 06:00:00+00:00
# 1      2019-06-17 08:00:00+00:00
# 2      2019-06-17 07:00:00+00:00
# 3      2019-06-17 06:00:00+00:00
# 4      2019-06-17 05:00:00+00:00
#                   ...
# 2063   2019-05-07 06:00:00+00:00
# 2064   2019-05-07 04:00:00+00:00
# 2065   2019-05-07 03:00:00+00:00
# 2066   2019-05-07 02:00:00+00:00
# 2067   2019-05-07 01:00:00+00:00
# Name: date.utc, Length: 3178, dtype: datetime64[ns, UTC]

# %%
air_quality_["date.utc"].min()
# Out:
# Timestamp('2019-05-07 01:00:00+0000', tz='UTC')

# %%
air_quality_["date.utc"].max()
# Out:
# Timestamp('2019-06-21 00:00:00+0000', tz='UTC')

# %%
air_quality_["date.utc"].max() - air_quality_["date.utc"].min()
# Out:
# Timedelta('44 days 23:00:00')

# %%
air_quality_["month"] = air_quality_["date.utc"].dt.month

# %%
air_quality_.head()
# Out:
#                    date.utc location parameter  value  month
# 0 2019-06-18 06:00:00+00:00  BETR801      pm25   18.0      6
# 1 2019-06-17 08:00:00+00:00  BETR801      pm25    6.5      6
# 2 2019-06-17 07:00:00+00:00  BETR801      pm25   18.5      6
# 3 2019-06-17 06:00:00+00:00  BETR801      pm25   16.0      6
# 4 2019-06-17 05:00:00+00:00  BETR801      pm25    7.5      6

# %%
air_quality_plot = air_quality_.groupby([air_quality_["date.utc"].dt.weekday, "location"])["value"].mean()

# %%
air_quality_plot.plot()
# Out:
# <Axes: xlabel='date.utc,location'>

# %%
fig, axs = plt.subplots(figsize=(12, 4))

air_quality_.groupby(air_quality_["date.utc"].dt.hour)["value"].mean().plot(
    kind='bar', rot=0, ax=axs
)

plt.xlabel("Hour of the day");  # custom x label using Matplotlib

plt.ylabel("$parameter$")
# Out:
# Text(0, 0.5, '$parameter$')

# %%
air_quality.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
mod_name = t_df["Name"].str.split(",")

# %%
t_df["Name"].head(50)
# Out:
# 0                                             anonymous
# 1                                             anonymous
# 2                                             anonymous
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                         Palsson, Master Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss Marguerite Rut
# 11                              Bonnell, Miss Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss Hulda Amanda Adolfina
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# 16                                  Rice, Master Eugene
# ...

# %%
mod_name.head(50)
# Out:
# 0                                           [anonymous]
# 1                                           [anonymous]
# 2                                           [anonymous]
# 3       [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                           [Allen,  Mr. William Henry]
# 5                                   [Moran,  Mr. James]
# 6                            [McCarthy,  Mr. Timothy J]
# 7                      [Palsson,  Master Gosta Leonard]
# 8     [Johnson,  Mrs. Oscar W (Elisabeth Vilhelmina ...
# 9                [Nasser,  Mrs. Nicholas (Adele Achem)]
# 10                    [Sandstrom,  Miss Marguerite Rut]
# 11                           [Bonnell,  Miss Elizabeth]
# 12                    [Saundercock,  Mr. William Henry]
# 13                       [Andersson,  Mr. Anders Johan]
# 14               [Vestrom,  Miss Hulda Amanda Adolfina]
# 15                  [Hewlett,  Mrs. (Mary D Kingcome) ]
# 16                               [Rice,  Master Eugene]
# ...

# %%
t_df["lastname"] = t_df["Name"].str.split(",").str.get(0)

# %%
t_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                          anonymous    male  22.0      1
# 1                                          anonymous  female  38.0      1
# 2                                          anonymous  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
'sub' in 'substring'
# Out:
# True

# %%
'pub' in 'substring'
# Out:
# False

# %%
t_df["Name"].str.contains("Countess")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
t_df[t_df["Name"].str.contains("Countess")]
# Out:
#      PassengerId  Survived  Pclass  \
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked lastname
# 759      0  110152  86.5   B77        S   Rothes

# %%
t_df.loc[t_df["Name"].str.len().idxmax(), "Name"]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'
